# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetalivarol/time-series-analysis-with-lstm/blob/master/lstm_time_series_DN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
mpl.rcParams['figure.figsize'] = (12, 7)
mpl.rcParams['axes.grid'] = False

df=pd.read_excel('/content/drive/My Drive/Colab Data/DN.linkterasend.xlsx', delimiter=';')
print('Number of rows and columns:', df.shape)
df.head(5)
# Out:
# Number of rows and columns: (717, 10)
#         Date  Units  IsGunuKatsayi  ...  IsKampanya  mforan  GeriOdemeDurum
# 0 2017-07-01     86         0.2500  ...           0       0            REIM
# 1 2017-07-02     12         0.0500  ...           0       0            REIM
# 2 2017-07-03    452         1.0000  ...           0       0            REIM
# 3 2017-07-04    284         1.0000  ...           0       0            REIM
# 4 2017-07-05    248         1.0000  ...           0       0            REIM
#
# [5 rows x 10 columns]

# %%
df['Units'] = pd.to_numeric(df['Units'], errors='coerce')
df = df.dropna(subset=['Units'])
df['Year'] = df['Date'].apply(lambda x: x.year)
df['Quarter'] = df['Date'].apply(lambda x: x.quarter)
df['Month'] = df['Date'].apply(lambda x: x.month)
df['Day'] = df['Date'].apply(lambda x: x.day)
df=df.loc[:,['Date','Units','IsGunuKatsayi','Year','Quarter','Month','Day']]
df.sort_values('Date', inplace=True, ascending=True)
df = df.reset_index(drop=True)
df["weekday"]=df.apply(lambda row: row["Date"].weekday(),axis=1)
df["weekday"] = (df["weekday"] < 5).astype(int)

print('Number of rows and columns after removing missing values:', df.shape)
print('The time series starts from: ', df.Date.min())
print('The time series ends on: ', df.Date.max())
# Out:
# Number of rows and columns after removing missing values: (717, 8)
# The time series starts from:  2017-07-01 00:00:00
# The time series ends on:  2019-07-31 00:00:00

# %%
df.head()
# Out:
#         Date  Units  IsGunuKatsayi  Year  Quarter  Month  Day  weekday
# 0 2017-07-01     86         0.2500  2017        3      7    1        0
# 1 2017-07-02     12         0.0500  2017        3      7    2        0
# 2 2017-07-03    452         1.0000  2017        3      7    3        1
# 3 2017-07-04    284         1.0000  2017        3      7    4        1
# 4 2017-07-05    248         1.0000  2017        3      7    5        1

# %%
rand_small = np.random.randint(0, 100, size=36)
rand_big = np.random.randint(0, 100, size=136)
def SampEn(U, m, r):
    """Compute Sample entropy"""
    def _maxdist(x_i, x_j):
        return max([abs(ua - va) for ua, va in zip(x_i, x_j)])

    def _phi(m):
        x = [[U[j] for j in range(i, i + m - 1 + 1)] for i in range(N - m + 1)]
        C = [len([1 for j in range(len(x)) if i != j and _maxdist(x[i], x[j]) <= r]) for i in range(len(x))]
        return sum(C)

    N = len(U)
    return -np.log(_phi(m+1) / _phi(m))

print(SampEn(df.Units, m=2, r=0.2*np.std(df.Units))) 
print(SampEn(rand_small, m=2, r=0.2*np.std(rand_small)))
print(SampEn(rand_big, m=2, r=0.2*np.std(rand_big)))
# Out:
# 1.1238032108114202
# 1.9459101490553135
# 2.5427262206768266

# %%
stat, p = stats.normaltest(df.Units)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Data looks Gaussian (fail to reject H0)')
else:
    print('Data does not look Gaussian (reject H0)')
# Out:
# Statistics=153.488, p=0.000
# Data does not look Gaussian (reject H0)

# %%
sns.distplot(df.Units);
print( 'Kurtosis of normal distribution: {}'.format(stats.kurtosis(df.Units)))
print( 'Skewness of normal distribution: {}'.format(stats.skew(df.Units)))
# Out:
# Kurtosis of normal distribution: 4.433246616541539
# Skewness of normal distribution: 0.905551141897705

# %%
df1=df.loc[:,['Date','Units']]
df1.set_index('Date',inplace=True)
df1.plot(figsize=(12,5))
plt.ylabel('Units')
plt.legend().set_visible(False)
plt.tight_layout()
plt.title('Units Time Series')
sns.despine(top=True)
plt.show();

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.subplots_adjust(wspace=0.2)
sns.boxplot(x="Year", y="Units", data=df)
plt.xlabel('Year')
plt.title('Box plot of Yearly Units')
sns.despine(left=True)
plt.tight_layout()
plt.subplot(1,2,2)
sns.boxplot(x="Quarter", y="Units", data=df)
plt.xlabel('Quarter')
plt.title('Box plot of Quarterly Units')
sns.despine(left=True)
plt.tight_layout();

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
df['Units'].hist(bins=50)
plt.title('Units Distribution')
plt.subplot(1,2,2)
stats.probplot(df['Units'], plot=plt);
df1.describe().T
# Out:
#          count     mean      std    min     25%      50%      75%       max
# Units 717.0000 241.6848 193.8700 0.0000 39.0000 284.0000 368.0000 1636.0000

# %%
fig = plt.figure(figsize=(18,16))
fig.subplots_adjust(hspace=.4)
ax1 = fig.add_subplot(5,1,1)
ax1.plot(df1['Units'].resample('D').mean(),linewidth=1)
ax1.set_title('Mean Units resampled over day')
ax1.tick_params(axis='both', which='major')

ax2 = fig.add_subplot(5,1,2, sharex=ax1)
ax2.plot(df1['Units'].resample('W').mean(),linewidth=1)
ax2.set_title('Mean Units resampled over week')
ax2.tick_params(axis='both', which='major')

ax3 = fig.add_subplot(5,1,3, sharex=ax1)
ax3.plot(df1['Units'].resample('M').mean(),linewidth=1)
ax3.set_title('Mean Units resampled over month')
ax3.tick_params(axis='both', which='major')

ax4  = fig.add_subplot(5,1,4, sharex=ax1)
ax4.plot(df1['Units'].resample('Q').mean(),linewidth=1)
ax4.set_title('Mean Units resampled over quarter')
ax4.tick_params(axis='both', which='major')

ax5  = fig.add_subplot(5,1,5, sharex=ax1)
ax5.plot(df1['Units'].resample('A').mean(),linewidth=1)
ax5.set_title('Mean Units resampled over year')
ax5.tick_params(axis='both', which='major');

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
df.groupby('Year').Units.agg('mean').plot()
plt.xlabel('')
plt.title('Mean Units by Year')

plt.subplot(2,2,2)
df.groupby('Quarter').Units.agg('mean').plot()
plt.xlabel('')
plt.title('Mean Units by Quarter')

plt.subplot(2,2,3)
df.groupby('Month').Units.agg('mean').plot()
plt.xlabel('')
plt.title('Mean Units by Month')

plt.subplot(2,2,4)
df.groupby('Day').Units.agg('mean').plot()
plt.xlabel('')
plt.title('Mean Units by Day');

# %%
pd.pivot_table(df, values = 'Units',columns = "Year", index = "Month").plot(subplots = True, figsize=(12, 12), layout=(3, 5), sharey=True);

# %%
dic={0:'Weekend',1:'Weekday'}
df['Day'] = df.weekday.map(dic)
a=plt.figure(figsize=(12,7)) 
plt1=sns.boxplot('Year','Units',hue='Day',width=0.6,fliersize=3,
                    data=df)                                                                                                                                                                                                                                                                                                                                                 
a.legend(loc='upper center', bbox_to_anchor=(0.5, 1.00), shadow=True, ncol=2)
sns.despine(left=True, bottom=True) 
plt.xlabel('')
plt.tight_layout()                                                                                                                  
plt.legend().set_visible(False);

# %%
plt1=sns.factorplot('Year','Units',hue='Day',
                    data=df, size=5, aspect=1.5, legend=False)                                                                                                                                                                                                                                                                                                                                             
plt.title('Factor Plot of Units by Weekend/Weekday')                                                             
plt.tight_layout()                                                                                                                  
sns.despine(left=True, bottom=True) 
plt.legend(loc='upper right');

# %%
df2=df1.resample('D', how=np.mean)

def test_stationarity(timeseries):
    rolmean = timeseries.rolling(window=10).mean()
    rolstd = timeseries.rolling(window=10).std()
    
    plt.figure(figsize=(14,8))
    sns.despine(left=True)
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')

    plt.legend(loc='best'); plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    print ('<Results of Dickey-Fuller Test>')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4],
                         index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
test_stationarity(df2.Units.dropna())
# Out:
# <Results of Dickey-Fuller Test>
# Test Statistic                 -3.7429
# p-value                         0.0035
# #Lags Used                     20.0000
# Number of Observations Used   696.0000
# Critical Value (1%)            -3.4398
# Critical Value (5%)            -2.8657
# Critical Value (10%)           -2.5690
# dtype: float64

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess
plt.rcParams.update({'xtick.bottom' : False, 'axes.titlepad':5})

df['ma9'] = df.Units.rolling(window=9).mean()
rolling_mean2 = df.Units.rolling(window=50).mean()
plt.plot(df.Date, df.Units, label='AMD')
plt.plot(df.Date, rolling_mean, label='AMD 9 Day SMA', color='orange')
plt.plot(df.Date, rolling_mean2, label='AMD 50 Day SMA', color='magenta')
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0a32aa9f7728> in <module>()
#       5 rolling_mean2 = df.Units.rolling(window=50).mean()
#       6 plt.plot(df.Date, df.Units, label='AMD')
# ----> 7 plt.plot(df.Date, rolling_mean, label='AMD 9 Day SMA', color='orange')
#       8 plt.plot(df.Date, rolling_mean2, label='AMD 50 Day SMA', color='magenta')
#       9 plt.legend(loc='upper left')
#
# NameError: name 'rolling_mean' is not defined

# %%
df['loess_5'] = pd.DataFrame(lowess(df.Units, np.arange(len(df.Units)), frac=0.03)[:, 1], index=df.index, columns=['Units'])

# %%
df.head(20)
# Out:
#          Date  Units  IsGunuKatsayi  Year  ...      Day  weekday      ma9  loess_5
# 0  2017-07-01     86         0.2500  2017  ...  Weekend        0      nan 187.0777
# 1  2017-07-02     12         0.0500  2017  ...  Weekend        0      nan 191.3988
# 2  2017-07-03    452         1.0000  2017  ...  Weekday        1      nan 195.3983
# 3  2017-07-04    284         1.0000  2017  ...  Weekday        1      nan 199.3180
# 4  2017-07-05    248         1.0000  2017  ...  Weekday        1      nan 203.3129
# 5  2017-07-06    259         1.0000  2017  ...  Weekday        1      nan 207.4313
# 6  2017-07-07    282         1.0000  2017  ...  Weekday        1      nan 211.6148
# 7  2017-07-08     28         0.2500  2017  ...  Weekend        0      nan 215.6217
# 8  2017-07-09      2         0.0500  2017  ...  Weekend        0 183.6667 218.8756
# 9  2017-07-10    337         1.0000  2017  ...  Weekday        1 211.5556 220.2442
# 10 2017-07-11    276         1.0000  2017  ...  Weekday        1 240.8889 217.4075
# 11 2017-07-12    240         1.0000  2017  ...  Weekday        1 217.3333 216.8011
# 12 2017-07-13    295         1.0000  2017  ...  Weekday        1 218.5556 219.1964
# 13 2017-07-14    268         1.0000  2017  ...  Weekday        1 220.7778 222.3550
# 14 2017-07-15      5         0.0500  2017  ...  Weekend        0 192.5556 223.7821
# 15 2017-07-16     10         0.0500  2017  ...  Weekend        0 162.3333 222.4601
# 16 2017-07-17    428         1.0000  2017  ...  Weekday        1 206.7778 218.3544
# 17 2017-07-18    260         1.0000  2017  ...  Weekday        1 235.4444 212.4569
# 18 2017-07-19    240         1.0000  2017  ...  Weekday        1 224.6667 207.1303
# 19 2017-07-20    292         1.0000  2017  ...  Weekday        1 226.4444 204.2736
#
# [20 rows x 10 columns]

# %%
dataset = df.ma9[8:717].values #numpy.ndarray
dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 30
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
from keras import optimizers
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.05))
model.add(LSTM(50,return_sequences = True))
model.add(Dropout(0.05))
model.add(LSTM(50,return_sequences = True))
model.add(Dropout(0.05))
model.add(LSTM(50))
model.add(Dropout(0.05))
model.add(Dense(1))
Adam=keras.optimizers.Adam(lr=0.001)
model.compile(loss='mean_squared_error', optimizer='Adam')

history = model.fit(X_train, Y_train, epochs=100, batch_size= 16, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience= 10)], verbose=1, shuffle=False)

model.summary()
# Out:
# Train on 536 samples, validate on 111 samples
# Epoch 1/100
# 536/536 [==============================] - 12s 22ms/step - loss: 0.0714 - val_loss: 0.0140
# Epoch 2/100
# 536/536 [==============================] - 0s 670us/step - loss: 0.0200 - val_loss: 0.0217
# Epoch 3/100
# 536/536 [==============================] - 0s 688us/step - loss: 0.0173 - val_loss: 0.0211
# Epoch 4/100
# 536/536 [==============================] - 0s 707us/step - loss: 0.0157 - val_loss: 0.0183
# Epoch 5/100
# 536/536 [==============================] - 0s 742us/step - loss: 0.0139 - val_loss: 0.0151
# Epoch 6/100
# 536/536 [==============================] - 0s 777us/step - loss: 0.0117 - val_loss: 0.0118
# Epoch 7/100
# 536/536 [==============================] - 0s 681us/step - loss: 0.0097 - val_loss: 0.0100
# Epoch 8/100
# 536/536 [==============================] - 0s 739us/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 9/100
# 536/536 [==============================] - 0s 658us/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 10/100
# 536/536 [==============================] - 0s 668us/step - loss: 0.0067 - val_loss: 0.0073
# Epoch 11/100
# 536/536 [==============================] - 0s 734us/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 12/100
# 536/536 [==============================] - 0s 667us/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 13/100
# 536/536 [==============================] - 0s 701us/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 14/100
# 536/536 [==============================] - 0s 777us/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 15/100
# 536/536 [==============================] - 0s 717us/step - loss: 0.0037 - val_loss: 0.0052
# Epoch 16/100
# 536/536 [==============================] - 0s 681us/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 17/100
# 536/536 [==============================] - 0s 673us/step - loss: 0.0033 - val_loss: 0.0051
# Epoch 18/100
# 536/536 [==============================] - 0s 693us/step - loss: 0.0034 - val_loss: 0.0051
# Epoch 19/100
# 536/536 [==============================] - 0s 689us/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 20/100
# 536/536 [==============================] - 0s 660us/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 21/100
# 536/536 [==============================] - 0s 659us/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 22/100
# 536/536 [==============================] - 0s 705us/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 23/100
# 536/536 [==============================] - 0s 722us/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 24/100
# 536/536 [==============================] - 0s 686us/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 25/100
# 536/536 [==============================] - 0s 703us/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 26/100
# 536/536 [==============================] - 0s 674us/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 27/100
# 536/536 [==============================] - 0s 688us/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 28/100
# 536/536 [==============================] - 0s 696us/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 29/100
# 536/536 [==============================] - 0s 671us/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 30/100
# 536/536 [==============================] - 0s 652us/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 31/100
# 536/536 [==============================] - 0s 693us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 32/100
# 536/536 [==============================] - 0s 713us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 33/100
# 536/536 [==============================] - 0s 706us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 34/100
# 536/536 [==============================] - 0s 787us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 35/100
# 536/536 [==============================] - 0s 739us/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 36/100
# 536/536 [==============================] - 0s 658us/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 37/100
# 536/536 [==============================] - 0s 667us/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 38/100
# 536/536 [==============================] - 0s 652us/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 39/100
# 536/536 [==============================] - 0s 727us/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 40/100
# 536/536 [==============================] - 0s 682us/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 41/100
# 536/536 [==============================] - 0s 681us/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 42/100
# 536/536 [==============================] - 0s 668us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 43/100
# 536/536 [==============================] - 0s 651us/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 44/100
# 536/536 [==============================] - 0s 684us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 45/100
# 536/536 [==============================] - 0s 687us/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 46/100
# 536/536 [==============================] - 0s 704us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 47/100
# 536/536 [==============================] - 0s 669us/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 48/100
# 536/536 [==============================] - 0s 688us/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 49/100
# 536/536 [==============================] - 0s 700us/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 50/100
# 536/536 [==============================] - 0s 659us/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 51/100
# 536/536 [==============================] - 0s 678us/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 52/100
# 536/536 [==============================] - 0s 697us/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 53/100
# 536/536 [==============================] - 0s 677us/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 54/100
# 536/536 [==============================] - 0s 681us/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 55/100
# 536/536 [==============================] - 0s 697us/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 56/100
# 536/536 [==============================] - 0s 646us/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 57/100
# 536/536 [==============================] - 0s 647us/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 58/100
# 536/536 [==============================] - 0s 656us/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 59/100
# 536/536 [==============================] - 0s 673us/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 60/100
# 536/536 [==============================] - 0s 676us/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 61/100
# 536/536 [==============================] - 0s 668us/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 62/100
# 536/536 [==============================] - 0s 633us/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 63/100
# 536/536 [==============================] - 0s 690us/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 64/100
# 536/536 [==============================] - 0s 684us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 65/100
# 536/536 [==============================] - 0s 686us/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 66/100
# 536/536 [==============================] - 0s 706us/step - loss: 0.0015 - val_loss: 0.0021
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_53 (LSTM)               (None, 1, 50)             16200
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 1, 50)             0
# _________________________________________________________________
# lstm_54 (LSTM)               (None, 1, 50)             20200
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1, 50)             0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 1, 50)             20200
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 1, 50)             0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 76,851
# Trainable params: 76,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 23.674296971532023
# Train Root Mean Squared Error: 29.577095712888152
# Test Mean Absolute Error: 23.191378300013472
# Test Root Mean Squared Error: 30.798293673665018

# %%
plt.figure(figsize=(12,7))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
aa=[x for x in range(111)]
plt.figure(figsize=(12,7))
plt.plot(aa, Y_test[0][:111], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:111], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Units', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
